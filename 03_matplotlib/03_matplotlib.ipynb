# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# **Example**

# %%
x = np.linspace(0,2*np.pi)
y = np.sin(x)
fig, ax =plt.subplots()
ax.plot(x,y)

# %% [markdown]
# **Exercise1**

# %%
alpha = 0.7
betha = 10
x = np.linspace(0,2*np.pi,1000)
y = np.exp(-1*alpha*x)*np.sin(betha*x)
fig, ax =plt.subplots()
ax.plot(x,y,linewidth=3,color='olivedrab')
ax.grid(True)
fig.tight_layout()

# %% [markdown]
# **Exercise 2**

# %%
df = pd.read_csv("tiobe-2020-clean.csv", index_col='Language')
df.head()
# Out:
#           Ratings
# Language
# C           17.38
# Java        11.96
# Python      11.72
# C++          7.56
# C#           3.95

# %%
bar_width = 0.30
x = np.arange(df.index.size)
fig, ax = plt.subplots(dpi=100)

ax.bar(x,df['Ratings'],bar_width, color='turquoise')

ax.set_xticks(x)
ax.set_xticklabels(df.index, rotation=90)
ax.yaxis.grid(color='lightgray')
ax.set_ylabel('Rating TIOBE (%)')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
fig.tight_layout()

# %% [markdown]
# **Exercise 3**

# %%
df = pd.read_csv("bmw-clean.csv")
df.head()
# Out:
#    Unnamed: 0      model  year  price transmission  mileage fuelType  tax  \
# 0           0   5 Series  2014  11200    Automatic    67068   Diesel  125
# 1           1   6 Series  2018  27000    Automatic    14827   Petrol  145
# 2           2   5 Series  2016  16000    Automatic    62794   Diesel  160
# 3           3   1 Series  2017  12750    Automatic    26676   Diesel  145
# 4           4   7 Series  2014  14500    Automatic    39554   Diesel  160
#
#     mpg  engineSize
# 0  57.6         2.0
# 1  42.8         2.0
# 2  51.4         3.0
# 3  72.4         1.5
# 4  50.4         3.0

# %%
x = df['mpg']
y = df['price']
color = df['year']

fig, ax = plt.subplots(figsize=(8,6), dpi=100)

p = ax.scatter(x,y,
                 s =30,
                 c=color,
                 vmin = color.min(),
                 vmax = color.max(),
                 alpha = 0.7,
                 edgecolors='none')

cb = fig.colorbar(p, ax=ax, label='Year', extend='max')   
cb.outline.set_visible(False)
ax.set_xlabel('Consumo (mpg)')
ax.set_ylabel('Precio(€)')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

fig.tight_layout()

# %% [markdown]
# **Exercise 4**

# %%
df = pd.read_csv("pokemon.csv", usecols = ['Speed'])
df.head()
# Out:
#    Speed
# 0     45
# 1     60
# 2     80
# 3     80
# 4     65

# %%
fig, ax = plt.subplots(figsize=(6, 4), dpi=100)
b = range (0,161,10)
ax.hist(df,
        bins = b,
        rwidth = 0.95,
        zorder = 2,
        color = 'tomato',
        alpha = 0.7)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xticks(b)
ax.yaxis.grid(color='mistyrose')

# %% [markdown]
# **Exercise 5**

# %%
df = pd.read_csv("euro-dollar-clean.csv")
df.head()
# Out:
#    year  month  day  dollar
# 0  2021      9   20  1.1711
# 1  2021      9   17  1.1780
# 2  2021      9   16  1.1763
# 3  2021      9   15  1.1824
# 4  2021      9   14  1.1814

# %%
df_ratings = df.groupby(['year','month'])['dollar'].mean().unstack()
ratings
# Out:
# month        1         2         3         4         5         6         7   \
# year
# 2010   1.359248  1.368570  1.356852  1.218700  1.256533  1.220850  1.277000
# 2011   1.335967  1.364895  1.399917  1.306638  1.434864  1.438841  1.426429
# 2012   1.290486  1.322410  1.320100  1.190824  1.223287  1.252629  1.228845
# 2013   1.328805  1.335905  1.296360  1.302600  1.298205  1.318875  1.308013
# 2014   1.361023  1.365850  1.382252  1.381250  1.373214  1.359238  1.353917
# 2015   1.162133  1.134965  1.083768  1.077930  1.114955  1.121323  1.099578
# 2016   1.085965  1.109295  1.109967  1.133919  1.131109  1.122891  1.106852
# 2017   1.061441  1.064265  1.068470  1.072267  1.105750  1.122945  1.151114
# 2018   1.219950  1.234780  1.233619  1.227630  1.181223  1.167829  1.168573
# 2019   1.141641  1.135115  1.130248  1.123825  1.118459  1.129340  1.121839
# 2020   1.110036  1.090500  1.106341  1.086190  1.090185  1.125459  1.146339
# 2021   1.217085  1.209790  1.189909  1.197910  1.214590  1.204709  1.182182
#
# month        8         9         10        11        12
# year
# 2010   1.289418  1.306700  1.389781  1.366095  1.322013
# 2011   1.434322  1.377000  1.370633  1.355573  1.258000
# 2012   1.239996  1.285570  1.297417  1.282773  1.311937
# 2013   1.330950  1.334790  1.363496  1.349290  1.370360
# 2014   1.331610  1.290136  1.267274  1.247220  1.233133
# 2015   1.113905  1.122118  1.123509  1.073600  1.087718
# 2016   1.121174  1.121209  1.102605  1.079895  1.054290
# 2017   1.180674  1.191457  1.175586  1.173800  1.183621
# 2018   1.154896  1.165870  1.148404  1.136686  1.138421
# 2019   1.112623  1.100390  1.105257  1.105095  1.111345
# 2020   1.182810  1.179241  1.177518  1.183790  1.216973
# 2021   1.177182  1.181693       NaN       NaN       NaN

# %%
fig, ax = plt.subplots(figsize=(8,6), dpi=100)
text_colors = ('black', 'white')
im = ax.imshow(ratings, cmap ='Blues')
cbar = fig.colorbar(im, ax=ax, extend='max')  
cbar.outline.set_visible(False)

x = ratings.columns
y = ratings.index

for i in range(len(y)):
    for j in range(len(x)):
        value = ratings.iloc[i, j]
        text_color = text_colors[int(im.norm(value) > 0.5)]  # color etiqueta
        ax.text(j, i, f'{value:.2f}', color=text_color, va='center', ha='center')

ax.set_xticks(range(len(x)))
ax.set_xticklabels(
    ['ENE', 'FEB', 'MAR', 'ABR', 'MAY', 'JUN', 'JUL', 'AGO', 'SEP', 'OCT', 'NOV', 'DIC'],
    rotation=90,
)

ax.set_yticks(range(len(y)))
ax.set_yticklabels(y)
ax.invert_yaxis()
ax.spines[:].set_visible(False)
fig.tight_layout()

# %% [markdown]
# **Exercise 6**

# %%
from matplotlib.dates import DateFormatter, DayLocator

df = pd.read_csv(
    'mwh-spain-2021-clean.csv',
    parse_dates=['Fecha'],
    index_col='Fecha',
)
df.head()
# Out:
#               MWh
# Fecha
# 2021-01-02  48.72
# 2021-01-03  46.93
# 2021-01-04  59.85
# 2021-01-05  67.55
# 2021-01-06  70.60

# %%
fig, ax = plt.subplots(figsize=(6, 3), dpi=100)

x = df.index
y = df.iloc[:, 0]

ax.plot(x, y, color='goldenrod')
plt.fill_between(x, y, alpha=0.2, color='gold')  # área

# Anotación del valor máximo
xmax, ymax = y.idxmax(), y.max()
ax.annotate(
    f'max={ymax}€',
    xy=(xmax, ymax),
    xytext=(-75, 0),
    textcoords='offset points',
    ha='center',
    va='center',
    arrowprops=dict(facecolor='black', shrink=0.05, width=3),
)

# Estilos para el eje x
ax.set_xlim(x.min(), x.max())
ax.xaxis.set_major_locator(DayLocator(interval=8))
ax.xaxis.set_major_formatter(DateFormatter('%d %b'))
ax.tick_params(axis='x', which='major', rotation=90)

# Estilos para el eje y
ax.set_ylim(0, 200)

# Rejilla
ax.grid(color='lightgray', linestyle='dashed')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.tight_layout()
